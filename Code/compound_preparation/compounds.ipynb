# %% [markdown]
# Pandas

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pathlib import Path

# %%
# reading given tsv file
with open("compound_chembl.tsv", 'r') as myfile: 
  with open("compound_chembl.csv", 'w') as csv_file:
    for line in myfile:
       
      # Replace every tab with comma
      fileContent = re.sub("\t", ",", line)
       
      # Writing into csv file
      csv_file.write(fileContent)
 
# output
print("Successfully made csv file")
# Out:
# Successfully made csv file

# %%
compounds = pd.read_csv("compound_chembl.csv")
compounds.head()
# Out:
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0      CHEMBL4516452           NaN                   0            269.30
# 1      CHEMBL4464070           NaN                   0            347.37
# 2      CHEMBL4582016           NaN                   0            331.37
# 3      CHEMBL4751565           NaN                   0            411.46
# 4      CHEMBL4787586           NaN                   0            461.56
#
#    #RO5 Violations  AlogP Compound Key  \
# 0                0   2.85          A40
# 1                0   3.65           A6
# 2                0   4.21          A21
# 3                1   5.44          WK5
# 4                1   5.00          WL8
#
#                                               Smiles Standard Type  \
# 0               COc1cccc2cc3c(cc12)C(=O)N(C(C)C)C3=O    Inhibition
# 1         COc1ccc(CN2C(=O)c3cc4cccc(OC)c4cc3C2=O)cc1    Inhibition
# 2            CCc1ccccc1N1C(=O)c2cc3cccc(OC)c3cc2C1=O    Inhibition
# ...

# %%
smiles = compounds[['Molecule ChEMBL ID', 'Smiles']]
smiles.head(5)
# Out:
#   Molecule ChEMBL ID                                             Smiles
# 0      CHEMBL4516452               COc1cccc2cc3c(cc12)C(=O)N(C(C)C)C3=O
# 1      CHEMBL4464070         COc1ccc(CN2C(=O)c3cc4cccc(OC)c4cc3C2=O)cc1
# 2      CHEMBL4582016            CCc1ccccc1N1C(=O)c2cc3cccc(OC)c3cc2C1=O
# 3      CHEMBL4751565  CC1(C)CCc2c(-c3nnco3)cc3c(OCc4ccc(C#N)cc4)cccc...
# 4      CHEMBL4787586  COc1cccc(COc2cccc3c4c(c(C(=O)N5CCOCC5)cc23)CCC...

# %%
# determining the name of the file
file_name = 'compounds_chembl_xlsx.xlsx'
  
# saving the excel
smiles.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %% [markdown]
# Decoys preparation

# %%
df = pd.DataFrame()
data_dir = Path("/Users/sashaolshanova/Library/Mobile Documents/com~apple~CloudDocs/Python/Mod_project/compound_preparation/decoys_csv")
for f in data_dir.glob("*.csv"): 
    decoys_1= pd.read_csv(f, delimiter=",", names=['smiles', 'other', 'other1'], engine='python')
    decoys_1.insert(0, "name", 'decoy')
    remove_other = decoys_1.drop("other", axis='columns')
    remove_other1 = remove_other.drop("other1", axis='columns')    
    df = pd.concat([df, remove_other1])
    #df.append(remove_other1, ignore_index= True)
df.to_csv('all_decoys.csv', index=False)
print('I did it')
# Out:
# I did it

# %%
df
# Out:
#      name                                             smiles
# 0   decoy         COc1ccc(cc1)CN2C(=O)c3cc4cccc(c4cc3C2=O)OC
# 1   decoy    CC(=CC(=O)OC(C)(C)[C@H]1Cc2cc3ccc(=O)oc3cc2O1)C
# 2   decoy           c1ccn2c(c1)nc(cc2=O)OC(=O)c3ccc(cc3Cl)Cl
# 3   decoy             Cc1c(c(no1)c2c(cccc2Cl)Cl)c3nc(on3)CCl
# 4   decoy        CC(C)[C@H]1Cc2c(sc3c2c4nnc(n4c(n3)SC)SC)CO1
# ..    ...                                                ...
# 46  decoy  c1ccc(cc1)c2nnc(o2)/C=C/c3ccc(cc3)n4nc5ccc6ccc...
# 47  decoy  Cc1ccc(cc1)c2nc(on2)c3ccc(nc3)N4CCN(CC4)c5ccc(...
# 48  decoy  Cc1ccc(cc1Cl)/N=C\2/N(CCCS2)C(=O)/C=C\c3cccc(c...
# 49  decoy  c1ccc(c(c1)c2nc3cc(ccc3o2)/N=C/c4ccc(cc4)[N+](...
# 50  decoy  Cc1c(c(n(n1)c2ccccc2)Cl)/C=N/c3ccc(cc3)c4ccc(c...
#
# [2703 rows x 2 columns]
